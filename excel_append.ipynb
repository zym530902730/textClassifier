# %%
import pandas as pd
import numpy as np
import os,sys,re
#将多个Excel文件合并成一个

import xlrd
import xlsxwriter

# %%
def readFasta(file):
    if os.path.exists(file) == False:
        print('Error: "' + file + '" does not exist.')
        sys.exit(1)

    with open(file) as f:
        records = f.read()

    if re.search('>', records) == None:
        print('The input file seems not in fasta format.')
        sys.exit(1)

    records = records.split('>')[1:]
    myFasta = []
    for fasta in records:
        array = fasta.split('\n')
        name, sequence = array[0].split()[0], re.sub('[^ARNDCQEGHILKMFPSTWYV-]', '-', ''.join(array[1:]).upper())
        myFasta.append([name, sequence])
    return myFasta

# %%
#打开一个excel文件
def open_xls(file):
    fh=xlrd.open_workbook(file)
    return fh

#获取excel中所有的sheet表
def getsheet(fh):
    return fh.sheets()

#获取sheet表的行数
def getnrows(fh,sheet):
    table=fh.sheets()[sheet]
    return table.nrows

#读取文件内容并返回行内容
def getFilect(file,shnum):
    fh=open_xls(file)
    table=fh.sheets()[shnum]
    num=table.nrows
    for row in range(num):
        rdata=table.row_values(row)
        datavalue.append(rdata)
    return datavalue

#获取sheet表的个数
def getshnum(fh):
    x=0
    sh=getsheet(fh)
    for sheet in sh:
        x+=1
    return x

# %%
# allxls=['C:/Users/Crow/Downloads/2019010304505093.csv',
# 'C:/Users/Crow/Downloads/2019010304481753.csv',
# 'C:/Users/Crow/Downloads/2019010304454479.csv',
# 'C:/Users/Crow/Downloads/2019010304440536.csv',
# 'C:/Users/Crow/Downloads/2019010304421125.csv',
# 'C:/Users/Crow/Downloads/2019010304323294.csv',
# 'C:/Users/Crow/Downloads/2019010304303714.csv',
# 'C:/Users/Crow/Downloads/2019010309160083.csv',
# 'C:/Users/Crow/Downloads/2019010309124186.csv',
# 'C:/Users/Crow/Downloads/2019010309105927.csv',
# 'C:/Users/Crow/Downloads/2019010309091596.csv',
# 'C:/Users/Crow/Downloads/2019010309074051.csv',
# 'C:/Users/Crow/Downloads/2019010309051756.csv',
# 'C:/Users/Crow/Downloads/201901030901481.csv',
# 'C:/Users/Crow/Downloads/2019010308591774.csv',
# 'C:/Users/Crow/Downloads/2019010308574686.csv',
# 'C:/Users/Crow/Downloads/2019010308545598.csv',
# 'C:/Users/Crow/Downloads/2019010308432126.csv',
# 'C:/Users/Crow/Downloads/2019010308392489.csv',
# 'C:/Users/Crow/Downloads/2019010308341614.csv',
# 'C:/Users/Crow/Downloads/2019010308312928.csv',
# 'C:/Users/Crow/Downloads/2019010308104998.csv',
# 'C:/Users/Crow/Downloads/2019010308075666.csv',
# 'C:/Users/Crow/Downloads/2019010308063328.csv',
# 'C:/Users/Crow/Downloads/2019010308042350.csv',
# 'C:/Users/Crow/Downloads/2019010307351847.csv',
# 'C:/Users/Crow/Downloads/201901030733438.csv',
# 'C:/Users/Crow/Downloads/2019010307313924.csv',
# 'C:/Users/Crow/Downloads/2019010307300718.csv',
# 'C:/Users/Crow/Downloads/2019010307281377.csv',
# 'C:/Users/Crow/Downloads/2019010307263085.csv',
# 'C:/Users/Crow/Downloads/2019010307232391.csv',
# 'C:/Users/Crow/Downloads/2019010307135618.csv',
for fl in allxls:
    fh= pd.read_csv(fl)
    data_score = data_score.append(fh)

# %%
data_score.to_csv('C:/Users/Crow/Desktop/CKSAAP_CrotSite2/result.csv')

# %%
# Out:
# 63278

# %%
# 读取CKSAAP_CrotSite_score
data = pd.read_csv('C:/Users/Crow/Desktop/CKSAAP_CrotSite/CKSAAP_CrotSite_15.csv')

# %%
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-80c7d069447b> in <module>
# ----> 1 data.head(5)
#
# NameError: name 'data' is not defined

# %%
raw_data = readFasta('C:/Users/Crow/Desktop/human_data_12.12/Step_11_IND/Test_29.fasta')

# %%
raw_data_list = []
for i in range(0,len(raw_data)):
    raw_data_list.append(raw_data[i][0].replace("''",""))

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
a = raw_data.index

# %%
for i in range(0,len(raw_data)):

# %%
data['Protein ID']
# Out:
# 0        O95782_935|0|testing
# 1         O95858_21|0|testing
# 2         O95858_51|0|testing
# 3         O95858_51|0|testing
# 4         O95858_53|0|testing
# 5         O95858_53|0|testing
# 6        O95858_142|0|testing
# 7        O95858_142|0|testing
# 8        O95858_142|0|testing
# 9        O95858_142|0|testing
# 10       O95858_150|0|testing
# 11       O95858_150|0|testing
# 12       O95858_150|0|testing
# 13       O95858_150|0|testing
# 14       O95858_151|0|testing
# 15       O95858_151|0|testing
# 16       O95858_151|0|testing
# 17       O95858_151|0|testing
# 18       O95858_151|0|testing
# 19       O95858_165|0|testing
# 20       O95858_165|0|testing
# 21       O95858_165|0|testing
# 22       O95858_201|0|testing
# 23       O95858_201|0|testing
# 24       O95858_205|0|testing
# 25       O95858_205|0|testing
# 26       O95858_278|0|testing
# 27         O95994_3|0|testing
# 28        O95994_26|0|testing
# 29        O95994_26|0|testing
#                  ...
# ...

# %%
data['Protein ID'] = data['Protein ID'].astype('category')

# %%
data['Protein ID'].cat.reorder_categories(raw_data_list, inplace=True)

# inplace = True，使 df生效
data.sort_values('Protein ID', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-decf6ba3388b> in <module>
#       3 # inplace = True，使 df生效
#       4 data.sort_values('Protein ID', inplace=True)
# ----> 5 df
#
# NameError: name 'df' is not defined

# %%
data
# Out:
#                  Protein ID  \tLysine_position  \
# 12264   A6NDG6_80|1|testing                  7
# 12265   A6NDG6_80|1|testing                 15
# 12269  A6NEN9_177|1|testing                 18
# 12266  A6NEN9_177|1|testing                  7
# 12267  A6NEN9_177|1|testing                  9
# 12268  A6NEN9_177|1|testing                 15
# 12270  A6NEN9_177|1|testing                 20
# 12271  A6NEN9_177|1|testing                 21
# 12275  B1AJZ9_513|1|testing                 25
# 12274  B1AJZ9_513|1|testing                 15
# 12272  B1AJZ9_513|1|testing                  3
# 12273  B1AJZ9_513|1|testing                 10
# 12276  O00116_454|1|testing                  9
# 12277  O00116_454|1|testing                 10
# 12279  O00116_454|1|testing                 17
# 12278  O00116_454|1|testing                 15
# 12281  O00116_476|1|testing                 21
# 12282  O00116_476|1|testing                 29
# 12280  O00116_476|1|testing                 15
# ...

# %%
data.to_csv('C:/Users/Crow/Desktop/CKSAAP_CrotSite/CKSAAP_CrotSite_sort.csv')
